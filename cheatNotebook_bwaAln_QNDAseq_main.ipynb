# %% [markdown]
# Bwa Aln hg38 + QDNAseq new version hg38

# %% [markdown]
# # This is a Notebook to run CNV analysis server
#
# I am using it to have the steps for the CNV analaysis in one go and notbook as pipeline, and it can be run it form here but is running really running from the terminal

# %%
# !pwd
#!ls
# Out:
# /DATA/home/l.gonzalez/Notebooks

# %%
import os, sys
import glob
import logging

# %% [markdown]
# ### Before starting the analysis we will check the QC of the fastq files usign fastqc
# To do that, please go to the cell below and change the path to the folder where the fastq files are, then run it

# %%
## This is to run with the Organids 50 and 51,

# !fastqc /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/markdup/*markdup.bam
# Out:
# Started analysis of 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 5% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 10% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 15% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 20% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 25% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 30% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 35% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 40% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 45% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 50% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 55% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 60% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 65% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 70% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 75% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 80% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 85% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 90% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 95% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Approx 100% complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Analysis complete for 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# Started analysis of 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 5% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 10% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 15% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 20% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 25% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 30% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 35% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 40% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 45% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 50% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 55% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 60% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 65% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 70% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 75% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 80% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 85% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 90% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 95% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Approx 100% complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Analysis complete for 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# Started analysis of 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 5% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 10% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 15% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 20% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 25% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 30% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 35% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 40% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 45% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 50% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 55% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 60% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 65% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 70% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 75% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 80% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 85% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 90% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 95% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Approx 100% complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Analysis complete for 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# Started analysis of 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 5% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 10% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 15% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 20% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 25% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 30% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 35% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 40% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 45% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 50% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 55% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 60% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 65% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 70% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 75% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 80% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 85% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 90% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Approx 95% complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam
# Analysis complete for 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam

# %% [markdown]
# ##### As an optional step we can run multiqc after fastqc to create a unified html files with all the fastqc to see then in one go

# %% [markdown]
# ## Run bwa aln for the mapping part single end, check first the QC with fastqc
# There is no need for trimming (conda)
# The CLI can be run directly

# %%
#Script:
#BWA ALN

#Ref
#/DATA/share/pipelines/lgleon/References/Ensembl/NGSfacility/Homo_sapiens.GRCh38.dna.primary_assembly.fa

#data
prj=/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq


for file in ${prj}/*.f*q.gz
do

   inputfqgz=$file
   #outputbam=${file/%.fastq.gz/.bam}  #  % means that suffixes are matched, # would mean prefixes"
   filenamestem=${file/%.f*q.gz/}
   
   echo "!!!!!!!!!!!!!! Expected final output {$filenamestem.markdup.bam}"

   bwa aln -t 32 -n 2 \
    /DATA/share/pipelines/lgleon/References/Ensembl/NGSfacility/Homo_sapiens.GRCh38.dna.primary_assembly.fa  \
    $inputfqgz | bwa samse -r '@RG\tID:inputfqgz\tSM:inputfqgz' \
    /DATA/share/pipelines/lgleon/References/Ensembl/NGSfacility/Homo_sapiens.GRCh38.dna.primary_assembly.fa \
    - $inputfqgz | samtools view -Su - | samtools sort - -o $filenamestem.sorted.bam > $filenamestem.sorted.bam

   picard MarkDuplicates -I $filenamestem.sorted.bam -O $filenamestem.markdup.bam -M $filenamestem.markdup_metrics.txt -ASSUME_SORTED true -CREATE_INDEX true -VALIDATION_STRINGENCY LENIENT

done

                        

mkdir fastQC
#mv *f*q.gz fastQC

mkdir sorted_bam
mv *sorted.bam sorted_bam
#rm *sorted.bam

mkdir markdup_bam
mv *markdup.bam markdup_bam

# %%
## Alignment with bwa aln, code is at /home/l.gonzalez/Notebooks/bash_R_scripts/1_bwaAln_hg38_lgl.sh
## Go to the folder where you want to save the results
## Check in the code, it is quite general but reference is hard copied
## this code I meant to be run from the same folder where teh fastq files are store


### Remember the project folder IS HARDCODE, need to be changed

# !bash /DATA/home/l.gonzalez/Notebooks/bash_R_scripts/alternatve_bwaAln_hg38_lgl.sh
# Out:
# !!!!!!!!!!!!!! Expected final output {/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam}
# [bwa_aln_core] calculate SA coordinate... 40.17 sec
# [bwa_aln_core] write to the disk... 0.05 sec
# [bwa_aln_core] 262144 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 39.62 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 5.42 sec
# [bwa_aln_core] refine gapped alignments... 1.30 sec
# [bwa_aln_core] print alignments... 0.44 sec
# [bwa_aln_core] 262144 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 524288 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 40.57 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.79 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.33 sec
# [bwa_aln_core] 524288 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 786432 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 44.30 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.73 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.34 sec
# [bwa_aln_core] 786432 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 1048576 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 40.51 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.70 sec
# [bwa_aln_core] refine gapped alignments... 0.56 sec
# [bwa_aln_core] print alignments... 0.34 sec
# [bwa_aln_core] 1048576 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 1310720 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 41.85 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.70 sec
# [bwa_aln_core] refine gapped alignments... 0.56 sec
# [bwa_aln_core] print alignments... 0.33 sec
# [bwa_aln_core] 1310720 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 1572864 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 40.25 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.79 sec
# [bwa_aln_core] refine gapped alignments... 0.56 sec
# [bwa_aln_core] print alignments... 0.34 sec
# [bwa_aln_core] 1572864 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 1835008 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 40.93 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.78 sec
# [bwa_aln_core] refine gapped alignments... 0.56 sec
# [bwa_aln_core] print alignments... 0.33 sec
# [bwa_aln_core] 1835008 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 2097152 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 40.40 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.77 sec
# [bwa_aln_core] refine gapped alignments... 0.56 sec
# [bwa_aln_core] print alignments... 0.34 sec
# [bwa_aln_core] 2097152 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 2359296 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 40.88 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.80 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.37 sec
# [bwa_aln_core] 2359296 sequences have been processed.
# 0.09 sec
# [bwa_aln_core] 2621440 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 39.79 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.24 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 2621440 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 2883584 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 37.41 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.06 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 2883584 sequences have been processed.
# 0.10 sec
# [bwa_aln_core] 3145728 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 41.03 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.21 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.36 sec
# [bwa_aln_core] 3145728 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 3407872 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 41.31 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.09 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 3407872 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 3670016 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 37.53 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.96 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 3670016 sequences have been processed.
# 0.11 sec
# [bwa_aln_core] 3932160 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 49.75 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.81 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 3932160 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 4194304 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 49.48 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.82 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 4194304 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 4456448 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.77 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.80 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.32 sec
# [bwa_aln_core] 4456448 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 4718592 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 48.72 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.83 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 4718592 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 4980736 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.16 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.83 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 4980736 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 5242880 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.25 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.84 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 5242880 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 5505024 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.07 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.75 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 5505024 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 5767168 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.81 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.74 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 5767168 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 6029312 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.71 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.74 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.32 sec
# [bwa_aln_core] 6029312 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 6291456 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.96 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.76 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 6291456 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 6553600 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.35 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.73 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 6553600 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 6815744 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.22 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.83 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 6815744 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 7077888 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.40 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.80 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 7077888 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 7340032 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.39 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.80 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 7340032 sequences have been processed.
# 0.09 sec
# [bwa_aln_core] 7602176 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.35 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.83 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 7602176 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 7864320 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 48.10 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.81 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 7864320 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 8126464 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 43.10 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.82 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 8126464 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 8388608 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.20 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.81 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 8388608 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 8650752 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.41 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.83 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 8650752 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 8912896 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.18 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.83 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.32 sec
# [bwa_aln_core] 8912896 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 9175040 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 44.13 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.82 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 9175040 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 9437184 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.87 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.84 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 9437184 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 9699328 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.75 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.81 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 9699328 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 9961472 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.39 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.83 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 9961472 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 10223616 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.63 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.81 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 10223616 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 10485760 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.54 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.83 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 10485760 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 10747904 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.96 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.84 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 10747904 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 11010048 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.57 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.82 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 11010048 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 11272192 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.74 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.79 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 11272192 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 11534336 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.17 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.80 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 11534336 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 11796480 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 48.84 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.78 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 11796480 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 12058624 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.02 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.78 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.36 sec
# [bwa_aln_core] 12058624 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 12320768 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.03 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.81 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 12320768 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 12582912 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.72 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.77 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 12582912 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 12845056 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.74 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.78 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 12845056 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 13107200 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.74 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.75 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 13107200 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 13369344 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 45.42 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.74 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 13369344 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 13631488 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 44.15 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.74 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 13631488 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 13893632 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 4.54 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.77 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 13893632 sequences have been processed.
# 0.01 sec
# [bwa_aln_core] 13917850 sequences have been processed.
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa aln -t 32 -n 2 /DATA/share/pipelines/lgleon/References/Ensembl/NGSfacility/Homo_sapiens.GRCh38.dna.primary_assembly.fa /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.fastq.gz
# [main] Real time: 415.375 sec; CPU: 2405.635 sec
# [bwa_aln_core] convert to sequence coordinate... 2.62 sec
# [bwa_aln_core] refine gapped alignments... 0.45 sec
# [bwa_aln_core] print alignments... 0.03 sec
# [bwa_aln_core] 13917850 sequences have been processed.
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa samse -r @RG\tID:inputfqgz\tSM:inputfqgz /DATA/share/pipelines/lgleon/References/Ensembl/NGSfacility/Homo_sapiens.GRCh38.dna.primary_assembly.fa - /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.fastq.gz
# [main] Real time: 418.482 sec; CPU: 272.692 sec
# [bam_sort_core] merging from 4 files and 1 in-memory blocks...
# INFO	2021-12-06 15:16:24	MarkDuplicates
#
# ********** NOTE: Picard's command line syntax is changing.
# **********
# ********** For more information, please see:
# ********** https://github.com/broadinstitute/picard/wiki/Command-Line-Syntax-Transition-For-Users-(Pre-Transition)
# **********
# ********** The command line looks like this in the new syntax:
# **********
# **********    MarkDuplicates -I /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.sorted.bam -O /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam -M /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup_metrics.txt -ASSUME_SORTED true -CREATE_INDEX false -VALIDATION_STRINGENCY LENIENT
# **********
#
#
# 15:16:25.876 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/opt/miniconda3/share/picard-2.18.29-0/picard.jar!/com/intel/gkl/native/libgkl_compression.so
# [Mon Dec 06 15:16:25 CET 2021] MarkDuplicates INPUT=[/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.sorted.bam] OUTPUT=/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam METRICS_FILE=/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup_metrics.txt ASSUME_SORTED=true VALIDATION_STRINGENCY=LENIENT CREATE_INDEX=false    MAX_SEQUENCES_FOR_DISK_READ_ENDS_MAP=50000 MAX_FILE_HANDLES_FOR_READ_ENDS_MAP=8000 SORTING_COLLECTION_SIZE_RATIO=0.25 TAG_DUPLICATE_SET_MEMBERS=false REMOVE_SEQUENCING_DUPLICATES=false TAGGING_POLICY=DontTag CLEAR_DT=true DUPLEX_UMI=false ADD_PG_TAG_TO_READS=true REMOVE_DUPLICATES=false DUPLICATE_SCORING_STRATEGY=SUM_OF_BASE_QUALITIES PROGRAM_RECORD_ID=MarkDuplicates PROGRAM_GROUP_NAME=MarkDuplicates READ_NAME_REGEX=<optimized capture of last three ':' separated fields as numeric values> OPTICAL_DUPLICATE_PIXEL_DISTANCE=100 MAX_OPTICAL_DUPLICATE_SET_SIZE=300000 VERBOSITY=INFO QUIET=false COMPRESSION_LEVEL=5 MAX_RECORDS_IN_RAM=500000 CREATE_MD5_FILE=false GA4GH_CLIENT_SECRETS=client_secrets.json USE_JDK_DEFLATER=false USE_JDK_INFLATER=false
# [Mon Dec 06 15:16:25 CET 2021] Executing as l.gonzalez@virchow on Linux 5.4.0-91-generic amd64; OpenJDK 64-Bit Server VM 10.0.2+13; Deflater: Intel; Inflater: Intel; Provider GCS is not available; Picard version: 2.18.29-SNAPSHOT
# INFO	2021-12-06 15:16:26	MarkDuplicates	Start of doWork freeMemory: 530785248; totalMemory: 536870912; maxMemory: 1073741824
# INFO	2021-12-06 15:16:26	MarkDuplicates	Reading input file and constructing read end information.
# INFO	2021-12-06 15:16:26	MarkDuplicates	Will retain up to 3890368 data points before spilling to disk.
# INFO	2021-12-06 15:16:28	MarkDuplicates	Read     1,000,000 records.  Elapsed time: 00:00:02s.  Time for last 1,000,000:    2s.  Last read position: 10:12,418,350
# INFO	2021-12-06 15:16:28	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:16:31	MarkDuplicates	Read     2,000,000 records.  Elapsed time: 00:00:05s.  Time for last 1,000,000:    2s.  Last read position: 11:107,419,368
# INFO	2021-12-06 15:16:31	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:16:33	MarkDuplicates	Read     3,000,000 records.  Elapsed time: 00:00:07s.  Time for last 1,000,000:    2s.  Last read position: 13:50,210,962
# INFO	2021-12-06 15:16:33	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:16:38	MarkDuplicates	Read     4,000,000 records.  Elapsed time: 00:00:12s.  Time for last 1,000,000:    4s.  Last read position: 15:60,850,626
# INFO	2021-12-06 15:16:38	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:16:40	MarkDuplicates	Read     5,000,000 records.  Elapsed time: 00:00:14s.  Time for last 1,000,000:    2s.  Last read position: 18:22,032,221
# INFO	2021-12-06 15:16:40	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:16:43	MarkDuplicates	Read     6,000,000 records.  Elapsed time: 00:00:17s.  Time for last 1,000,000:    2s.  Last read position: 2:96,074,520
# INFO	2021-12-06 15:16:43	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:16:45	MarkDuplicates	Read     7,000,000 records.  Elapsed time: 00:00:19s.  Time for last 1,000,000:    2s.  Last read position: 20:38,061,569
# INFO	2021-12-06 15:16:45	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:16:49	MarkDuplicates	Read     8,000,000 records.  Elapsed time: 00:00:23s.  Time for last 1,000,000:    3s.  Last read position: 3:123,764,868
# INFO	2021-12-06 15:16:49	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:16:52	MarkDuplicates	Read     9,000,000 records.  Elapsed time: 00:00:26s.  Time for last 1,000,000:    2s.  Last read position: 4:155,670,038
# INFO	2021-12-06 15:16:52	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:16:54	MarkDuplicates	Read    10,000,000 records.  Elapsed time: 00:00:28s.  Time for last 1,000,000:    2s.  Last read position: 6:58,208,645
# INFO	2021-12-06 15:16:54	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:16:56	MarkDuplicates	Read    11,000,000 records.  Elapsed time: 00:00:30s.  Time for last 1,000,000:    2s.  Last read position: 7:93,633,807
# INFO	2021-12-06 15:16:56	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:17:00	MarkDuplicates	Read    12,000,000 records.  Elapsed time: 00:00:34s.  Time for last 1,000,000:    3s.  Last read position: 8:115,764,752
# INFO	2021-12-06 15:17:00	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# Ignoring SAM validation error: ERROR: Record 12569362, Read name D00608:266:CCYKGANXX:2:2304:12670:70771, MAPQ should be 0 for unmapped read.
# Ignoring SAM validation error: ERROR: Record 
MAPQ should be 0 for unmapped read.
# Ignoring SAM validation error: ERROR: Record 12610004, Read name D00608:266:CCYKGANXX:2:1212:19529:60489, MAPQ should be 0 for unmapped read.
# Ignoring SAM validation error: ERROR: Record 13340736, Read name D00608:266:CCYKGANXX:2:2205:20485:6847, MAPQ should be 0 for unmapped read.
# Ignoring SAM validation error: ERROR: Record 13367766, Read name D00608:266:CCYKGANXX:2:2316:10999:22185, MAPQ should be 0 for unmapped read.
# Ignoring SAM validation error: ERROR: Record 13370037, Read name D00608:266:CCYKGANXX:2:1110:20628:42326, MAPQ should be 0 for unmapped read.
# INFO	2021-12-06 15:18:53	MarkDuplicates	Before output close freeMemory: 527588976; totalMemory: 536870912; maxMemory: 1073741824
# INFO	2021-12-06 15:18:53	MarkDuplicates	After output close freeMemory: 527588904; totalMemory: 536870912; maxMemory: 1073741824
# [Mon Dec 06 15:18:53 CET 2021] picard.sam.markduplicates.MarkDuplicates done. Elapsed time: 2.47 minutes.
# Runtime.totalMemory()=536870912
# !!!!!!!!!!!!!! Expected final output {/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam}
# [bwa_aln_core] calculate SA coordinate... 49.84 sec
# [bwa_aln_core] write to the disk... 0.07 sec
# [bwa_aln_core] 262144 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 54.90 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 5.20 sec
# [bwa_aln_core] refine gapped alignments... 0.66 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 262144 sequences have been processed.
# 0.10 sec
# [bwa_aln_core] 524288 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 53.99 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.96 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 524288 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 786432 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 62.28 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.81 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 786432 sequences have been processed.
# 0.09 sec
# [bwa_aln_core] 1048576 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 51.93 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.85 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 1048576 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 1310720 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.64 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.83 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 1310720 sequences have been processed.
# 0.09 sec
# [bwa_aln_core] 1572864 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 52.43 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 5.00 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.36 sec
# [bwa_aln_core] 1572864 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 1835008 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 54.76 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.88 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 1835008 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 2097152 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.53 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.81 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 2097152 sequences have been processed.
# 0.10 sec
# [bwa_aln_core] 2359296 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 53.81 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.88 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 2359296 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 2621440 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 52.86 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.84 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 2621440 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 2883584 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 48.74 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.78 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 2883584 sequences have been processed.
# 0.10 sec
# [bwa_aln_core] 3145728 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 53.25 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.85 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.35 sec
# [bwa_aln_core] 3145728 sequences have been processed.
# 0.10 sec
# [bwa_aln_core] 3407872 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 54.20 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.90 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 3407872 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 3670016 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 54.54 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.87 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 3670016 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 3932160 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 53.70 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.86 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 3932160 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 4194304 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 54.54 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.83 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 4194304 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 4456448 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 53.20 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.14 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 4456448 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 4718592 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 53.37 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.86 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 4718592 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 4980736 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.18 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.79 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 4980736 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 5242880 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 54.40 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.29 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.35 sec
# [bwa_aln_core] 5242880 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 5505024 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 58.60 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.09 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 5505024 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 5767168 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 52.52 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.86 sec
# [bwa_aln_core] refine gapped alignments... 0.61 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 5767168 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 6029312 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 53.37 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.08 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.35 sec
# [bwa_aln_core] 6029312 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 6291456 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 51.18 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.80 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.35 sec
# [bwa_aln_core] 6291456 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 6553600 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 51.86 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.08 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 6553600 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 6815744 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 50.36 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.84 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 6815744 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 7077888 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 52.79 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.82 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.36 sec
# [bwa_aln_core] 7077888 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 7340032 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 52.71 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.82 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 7340032 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 7602176 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.48 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.80 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.36 sec
# [bwa_aln_core] 7602176 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 7864320 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 51.59 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.86 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 7864320 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 8126464 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 47.47 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.35 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 8126464 sequences have been processed.
# 0.09 sec
# [bwa_aln_core] 8388608 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 7.29 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.77 sec
# [bwa_aln_core] refine gapped alignments... 0.70 sec
# [bwa_aln_core] print alignments... 0.31 sec
# [bwa_aln_core] 8388608 sequences have been processed.
# 0.01 sec
# [bwa_aln_core] 8424795 sequences have been processed.
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa aln -t 32 -n 2 /DATA/share/pipelines/lgleon/References/Ensembl/NGSfacility/Homo_sapiens.GRCh38.dna.primary_assembly.fa /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.fastq.gz[bwa_aln_core] convert to sequence coordinate...
# [main] Real time: 255.653 sec; CPU: 1705.629 sec
# 2.81 sec
# [bwa_aln_core] refine gapped alignments... 0.46 sec
# [bwa_aln_core] print alignments... 0.04 sec
# [bwa_aln_core] 8424795 sequences have been processed.
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa samse -r @RG\tID:inputfqgz\tSM:inputfqgz /DATA/share/pipelines/lgleon/References/Ensembl/NGSfacility/Homo_sapiens.GRCh38.dna.primary_assembly.fa - /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.fastq.gz
# [main] Real time: 258.962 sec; CPU: 170.669 sec
# [bam_sort_core] merging from 2 files and 1 in-memory blocks...
# INFO	2021-12-06 15:23:41	MarkDuplicates
#
# ********** NOTE: Picard's command line syntax is changing.
# **********
# ********** For more information, please see:
# ********** https://github.com/broadinstitute/picard/wiki/Command-Line-Syntax-Transition-For-Users-(Pre-Transition)
# **********
# ********** The command line looks like this in the new syntax:
# **********
# **********    MarkDuplicates -I /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.sorted.bam -O /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam -M /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup_metrics.txt -ASSUME_SORTED true -CREATE_INDEX false -VALIDATION_STRINGENCY LENIENT
# **********
#
#
# 15:23:41.729 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/opt/miniconda3/share/picard-2.18.29-0/picard.jar!/com/intel/gkl/native/libgkl_compression.so
# [Mon Dec 06 15:23:41 CET 2021] MarkDuplicates INPUT=[/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.sorted.bam] OUTPUT=/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam METRICS_FILE=/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup_metrics.txt ASSUME_SORTED=true VALIDATION_STRINGENCY=LENIENT CREATE_INDEX=false    MAX_SEQUENCES_FOR_DISK_READ_ENDS_MAP=50000 MAX_FILE_HANDLES_FOR_READ_ENDS_MAP=8000 SORTING_COLLECTION_SIZE_RATIO=0.25 TAG_DUPLICATE_SET_MEMBERS=false REMOVE_SEQUENCING_DUPLICATES=false TAGGING_POLICY=DontTag CLEAR_DT=true DUPLEX_UMI=false ADD_PG_TAG_TO_READS=true REMOVE_DUPLICATES=false DUPLICATE_SCORING_STRATEGY=SUM_OF_BASE_QUALITIES PROGRAM_RECORD_ID=MarkDuplicates PROGRAM_GROUP_NAME=MarkDuplicates READ_NAME_REGEX=<optimized capture of last three ':' separated fields as numeric values> OPTICAL_DUPLICATE_PIXEL_DISTANCE=100 MAX_OPTICAL_DUPLICATE_SET_SIZE=300000 VERBOSITY=INFO QUIET=false COMPRESSION_LEVEL=5 MAX_RECORDS_IN_RAM=500000 CREATE_MD5_FILE=false GA4GH_CLIENT_SECRETS=client_secrets.json USE_JDK_DEFLATER=false USE_JDK_INFLATER=false
# [Mon Dec 06 15:23:41 CET 2021] Executing as l.gonzalez@virchow on Linux 5.4.0-91-generic amd64; OpenJDK 64-Bit Server VM 10.0.2+13; Deflater: Intel; Inflater: Intel; Provider GCS is not available; Picard version: 2.18.29-SNAPSHOT
# INFO	2021-12-06 15:23:41	MarkDuplicates	Start of doWork freeMemory: 530785792; totalMemory: 536870912; maxMemory: 1073741824
# INFO	2021-12-06 15:23:41	MarkDuplicates	Reading input file and constructing read end information.
# ...
# [bwa_aln_core] calculate SA coordinate... 49.57 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.74 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 2097152 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 2359296 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 49.98 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.93 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 2359296 sequences have been processed.
# 0.09 sec
# [bwa_aln_core] 2621440 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 56.06 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.90 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 2621440 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 2883584 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 50.91 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.77 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 2883584 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 3145728 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 57.24 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.80 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.35 sec
# [bwa_aln_core] 3145728 sequences have been processed.
# 0.09 sec
# [bwa_aln_core] 3407872 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 57.33 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.89 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 3407872 sequences have been processed.
# 0.09 sec
# [bwa_aln_core] 3670016 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 55.26 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.90 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 3670016 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 3932160 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 53.57 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.79 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 3932160 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 4194304 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 55.51 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.82 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 4194304 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 4456448 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 57.03 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.84 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.29 sec
# [bwa_aln_core] 4456448 sequences have been processed.
# 0.08 sec
# [bwa_aln_core] 4718592 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 56.31 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.80 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 4718592 sequences have been processed.
# 0.12 sec
# [bwa_aln_core] 4980736 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 62.22 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.76 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 4980736 sequences have been processed.
# 0.09 sec
# [bwa_aln_core] 5242880 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 62.78 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.75 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 5242880 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 5505024 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 63.30 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.73 sec
# [bwa_aln_core] refine gapped alignments... 0.57 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 5505024 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 5767168 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 63.17 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.74 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 5767168 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 6029312 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 62.63 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.75 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.34 sec
# [bwa_aln_core] 6029312 sequences have been processed.
# 0.10 sec
# [bwa_aln_core] 6291456 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 62.20 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.79 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 6291456 sequences have been processed.
# 0.05 sec
# [bwa_aln_core] 6553600 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 57.37 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.75 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 6553600 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 6815744 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 59.01 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.77 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 6815744 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 7077888 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 50.61 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.75 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 7077888 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 7340032 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 54.98 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 4.93 sec
# [bwa_aln_core] refine gapped alignments... 0.60 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 7340032 sequences have been processed.
# 0.06 sec
# [bwa_aln_core] 7602176 sequences have been processed.
# [bwa_aln_core] calculate SA coordinate... 46.26 sec
# [bwa_aln_core] write to the disk... [bwa_aln_core] convert to sequence coordinate... 3.75 sec
# [bwa_aln_core] refine gapped alignments... 0.58 sec
# [bwa_aln_core] print alignments... 0.30 sec
# [bwa_aln_core] 7602176 sequences have been processed.
# 0.07 sec
# [bwa_aln_core] 7846548 sequences have been processed.
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa aln -t 32 -n 2 /DATA/share/pipelines/lgleon/References/Ensembl/NGSfacility/Homo_sapiens.GRCh38.dna.primary_assembly.fa /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.fastq.gz
# [main] Real time: 234.873 sec; CPU: 1703.221 sec
# [bwa_aln_core] convert to sequence coordinate... 4.00 sec
# [bwa_aln_core] refine gapped alignments... 0.59 sec
# [bwa_aln_core] print alignments... 0.28 sec
# [bwa_aln_core] 7846548 sequences have been processed.
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa samse -r @RG\tID:inputfqgz\tSM:inputfqgz /DATA/share/pipelines/lgleon/References/Ensembl/NGSfacility/Homo_sapiens.GRCh38.dna.primary_assembly.fa - /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.fastq.gz
# [main] Real time: 239.762 sec; CPU: 152.110 sec
# [bam_sort_core] merging from 2 files and 1 in-memory blocks...
# INFO	2021-12-06 15:33:31	MarkDuplicates
#
# ********** NOTE: Picard's command line syntax is changing.
# **********
# ********** For more information, please see:
# ********** https://github.com/broadinstitute/picard/wiki/Command-Line-Syntax-Transition-For-Users-(Pre-Transition)
# **********
# ********** The command line looks like this in the new syntax:
# **********
# **********    MarkDuplicates -I /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.sorted.bam -O /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam -M /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup_metrics.txt -ASSUME_SORTED true -CREATE_INDEX false -VALIDATION_STRINGENCY LENIENT
# **********
#
#
# 15:33:31.414 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/opt/miniconda3/share/picard-2.18.29-0/picard.jar!/com/intel/gkl/native/libgkl_compression.so
# [Mon Dec 06 15:33:31 CET 2021] MarkDuplicates INPUT=[/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.sorted.bam] OUTPUT=/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam METRICS_FILE=/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup_metrics.txt ASSUME_SORTED=true VALIDATION_STRINGENCY=LENIENT CREATE_INDEX=false    MAX_SEQUENCES_FOR_DISK_READ_ENDS_MAP=50000 MAX_FILE_HANDLES_FOR_READ_ENDS_MAP=8000 SORTING_COLLECTION_SIZE_RATIO=0.25 TAG_DUPLICATE_SET_MEMBERS=false REMOVE_SEQUENCING_DUPLICATES=false TAGGING_POLICY=DontTag CLEAR_DT=true DUPLEX_UMI=false ADD_PG_TAG_TO_READS=true REMOVE_DUPLICATES=false DUPLICATE_SCORING_STRATEGY=SUM_OF_BASE_QUALITIES PROGRAM_RECORD_ID=MarkDuplicates PROGRAM_GROUP_NAME=MarkDuplicates READ_NAME_REGEX=<optimized capture of last three ':' separated fields as numeric values> OPTICAL_DUPLICATE_PIXEL_DISTANCE=100 MAX_OPTICAL_DUPLICATE_SET_SIZE=300000 VERBOSITY=INFO QUIET=false COMPRESSION_LEVEL=5 MAX_RECORDS_IN_RAM=500000 CREATE_MD5_FILE=false GA4GH_CLIENT_SECRETS=client_secrets.json USE_JDK_DEFLATER=false USE_JDK_INFLATER=false
# [Mon Dec 06 15:33:31 CET 2021] Executing as l.gonzalez@virchow on Linux 5.4.0-91-generic amd64; OpenJDK 64-Bit Server VM 10.0.2+13; Deflater: Intel; Inflater: Intel; Provider GCS is not available; Picard version: 2.18.29-SNAPSHOT
# INFO	2021-12-06 15:33:31	MarkDuplicates	Start of doWork freeMemory: 530785808; totalMemory: 536870912; maxMemory: 1073741824
# INFO	2021-12-06 15:33:31	MarkDuplicates	Reading input file and constructing read end information.
# INFO	2021-12-06 15:33:31	MarkDuplicates	Will retain up to 3890368 data points before spilling to disk.
# INFO	2021-12-06 15:33:34	MarkDuplicates	Read     1,000,000 records.  Elapsed time: 00:00:02s.  Time for last 1,000,000:    2s.  Last read position: 11:22,389,014
# INFO	2021-12-06 15:33:34	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:33:36	MarkDuplicates	Read     2,000,000 records.  Elapsed time: 00:00:05s.  Time for last 1,000,000:    2s.  Last read position: 15:30,075,589
# INFO	2021-12-06 15:33:36	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:33:39	MarkDuplicates	Read     3,000,000 records.  Elapsed time: 00:00:07s.  Time for last 1,000,000:    2s.  Last read position: 19:19,348,934
# INFO	2021-12-06 15:33:39	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:33:43	MarkDuplicates	Read     4,000,000 records.  Elapsed time: 00:00:12s.  Time for last 1,000,000:    4s.  Last read position: 21:42,750,992
# INFO	2021-12-06 15:33:43	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:33:46	MarkDuplicates	Read     5,000,000 records.  Elapsed time: 00:00:14s.  Time for last 1,000,000:    2s.  Last read position: 5:40,428,287
# INFO	2021-12-06 15:33:46	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# INFO	2021-12-06 15:33:48	MarkDuplicates	Read     6,000,000 records.  Elapsed time: 00:00:17s.  Time for last 1,000,000:    2s.  Last read position: 7:152,272,244
# INFO	2021-12-06 15:33:48	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# Ignoring SAM validation error: ERROR: Record 6628090, Read name D00608:266:CCYKGANXX:2:1208:14816:76291, MAPQ should be 0 for unmapped read.
# Ignoring SAM validation error: ERROR: Record 6639891, Read name D00608:266:CCYKGANXX:2:2216:1634:61909, MAPQ should be 0 for unmapped read.
# INFO	2021-12-06 15:33:51	MarkDuplicates	Read     7,000,000 records.  Elapsed time: 00:00:19s.  Time for last 1,000,000:    2s.  Last read position: GL000220.1:122,270
# INFO	2021-12-06 15:33:51	MarkDuplicates	Tracking 0 as yet unmatched pairs. 0 records in RAM.
# Ignoring SAM validation error: ERROR: Record 7033186, Read name D00608:266:CCYKGANXX:2:2205:1423:15351, MAPQ should be 0 for unmapped read.
# INFO	2021-12-06 15:33:51	MarkDuplicates	Read 7033668 records. 0 pairs never matched.
# INFO	2021-12-06 15:33:52	MarkDuplicates	After buildSortedReadEndLists freeMemory: 512122936; totalMemory: 536870912; maxMemory: 1073741824
# INFO	2021-12-06 15:33:52	MarkDuplicates	Will retain up to 33554432 duplicate indices before spilling to disk.
# INFO	2021-12-06 15:33:52	MarkDuplicates	Traversing read pair information and detecting duplicates.
# INFO	2021-12-06 15:33:52	MarkDuplicates	Traversing fragment information and detecting duplicates.
# INFO	2021-12-06 15:33:52	SortingCollection	Creating merging iterator from 2 files
# INFO	2021-12-06 15:33:53	MarkDuplicates	Sorting list of duplicate records.
# INFO	2021-12-06 15:33:53	MarkDuplicates	After generateDuplicateIndexes freeMemory: 258493616; totalMemory: 536870912; maxMemory: 1073741824
# INFO	2021-12-06 15:33:53	MarkDuplicates	Marking 69109 records as duplicates.
# INFO	2021-12-06 15:33:53	MarkDuplicates	Found 0 optical duplicate clusters.
# INFO	2021-12-06 15:33:53	MarkDuplicates	Reads are assumed to be ordered by: coordinate
# Ignoring SAM validation error: ERROR: Record 6628090, Read name D00608:266:CCYKGANXX:2:1208:14816:76291, MAPQ should be 0 for unmapped read.
# Ignoring SAM validation error: ERROR: Record 6639891, Read name D00608:266:CCYKGANXX:2:2216:1634:61909, MAPQ should be 0 for unmapped read.
# Ignoring SAM validation error: ERROR: Record 7033186, Read name D00608:266:CCYKGANXX:2:2205:1423:15351, MAPQ should be 0 for unmapped read.
# INFO	2021-12-06 15:34:54	MarkDuplicates	Before output close freeMemory: 527591528; totalMemory: 536870912; maxMemory: 1073741824
# INFO	2021-12-06 15:34:54	MarkDuplicates	After output close freeMemory: 527591528; totalMemory: 536870912; maxMemory: 1073741824
# [Mon Dec 06 15:34:55 CET 2021] picard.sam.markduplicates.MarkDuplicates done. Elapsed time: 1.39 minutes.
# Runtime.totalMemory()=536870912
# mv: cannot stat '*.sorted.bam': No such file or directory
# mv: cannot stat '*markdup.bam': No such file or directory

# %% [markdown]
# #### Check the results,
# put them in the appropiate folders. Folder should be created in the process, but better check

# %% [markdown]
# ### Indexing the bam files to create the bai, otherwise we can not continue

# %%
# for Indexing the bam I have a tiny script that work quite nicely
### Remember the project folder IS HARDCODE, need to be changed

##WORKS

# !bash /DATA/home/l.gonzalez/Notebooks/bash_R_scripts/indexing.sh
# Out:
# indexing: /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/markdup/5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup.bam
# indexing: /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/markdup/5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup.bam
# indexing: /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/markdup/5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup.bam
# indexing: /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/markdup/5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup.bam

# %%
#!/bin/bash
#prj=/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/markdup
prj=/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/markdup
for i in ${prj}/*markdup.bam

do

echo "indexing: "$i
samtools index $i $i".bai"

done

# %% [markdown]
# ### After the analysis we will check the QC of the steps that we ran
# To do that, please go to the cell below and change the path to the folders where the fastqc files are, also the bam/bai files and multiqc will create a html with all the files

# %%
# !multiqc /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq/
# Out:
# [WARNING]         multiqc : MultiQC Version v1.11 now available!
# [INFO   ]         multiqc : This is MultiQC v1.10.1
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching   : /DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/fastq
# Searching   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 36/36  ATCGCA_S41_R1_001.markdup_fastqc.html.html
# [INFO   ]          picard : Found 4 MarkDuplicates reports
# [INFO   ]          fastqc : Found 4 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : multiqc_report.html
# [INFO   ]         multiqc : Data        : multiqc_data
# [INFO   ]         multiqc : MultiQC complete

# %% [markdown]
# ## Run QDNAseq for the calling,
# This new script, modified form Erik run from bam to called
# The CLI can be run directly but using R
#
# The code have some hardcode parts, path to project directory(output) and path to bam files (input)
# If you wanna run it with hg38, not need to change that part
# For the bin size it should be change also inside the code, for the calling and devawing
#
# To make those cahnges, there are three options:
# - Open the file here using the notebooks
# - Open in Rstudio
# - Open in the terminal
#
# Since it is a Rmarkdown file there are also two ways to run it:
# - Inside the Rstudio, step/chunk by step/chunk
# - From terminal (easier)

# %%
# To run as CLI
# Here is line of code to run in the Terminal (cliking here it will run it there, as knit)
# !R -e "rmarkdown::render('/DATA/share/pipelines/lgleon/IntEnd/DNA/Shallow_Seq/Results_QDNAseqFlow/BatchD_9-10/btD_hg38_100kb/QDNASeq_hg38_IntEnd_btD_server100kb.Rmd')" 

###Do not use R4.0###
#!/opt/R/4.0.4/bin/Rscript -e "rmarkdown::render('/DATA/share/pipelines/lgleon/NGS_protocol/results_QDNAseq/normalS/QDNASeqFlow_hg38_30Kb.Rmd')"

#The General Code, which is not, it is at 
# !R -e "/home/l.gonzalez/Notebooks/bash_R_scripts/QDNASeqFlow_hg38_NGSprotocol_30Kb.Rmd"
#The best way to work is make a copy of the general one, in the results folder, and run it form there
#as a knit it will create a html file at the same time
# Out:
# R version 3.6.3 (2020-02-29) -- "Holding the Windsock"
# Copyright (C) 2020 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
#   Natural language support but running in an English locale
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# > rmarkdown::render('/DATA/share/pipelines/lgleon/IntEnd/DNA/Shallow_Seq/Results_QDNAseqFlow/BatchD_9-10/btD_hg38_100kb/QDNASeq_hg38_IntEnd_btD_server100kb.Rmd')
#
#
# processing file: QDNASeq_hg38_IntEnd_btD_server100kb.Rmd
#   |..                                                                    |   3%
#   ordinary text without R code
#
#   |....                                                                  |   6%
# label: unnamed-chunk-1 (with options)
# List of 1
#  $ include: logi FALSE
#
#   |.......                                                               |   9%
#   ordinary text without R code
#
#   |.........                                                             |  12%
# label: setup (with options)
# List of 1
#  $ include: logi FALSE
#
#   |...........                                                           |  16%
#   ordinary text without R code
#
#   |.............                                                         |  19%
# label: functions (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#   |...............                                                       |  22%
#   ordinary text without R code
#
#   |..................                                                    |  25%
# label: wd (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#   |....................                                                  |  28%
#   ordinary text without R code
#
#   |......................                                                |  31%
# label: paths (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#   |........................                                              |  34%
#   ordinary text without R code
#
#   |..........................                                            |  38%
# label: bam2smooth (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#     6322_1_T20-60638_I-1 (1 of 177): binned read counts loaded from cache
#     6322_10_T20-60664_I-1 (2 of 177): binned read counts loaded from cache
#     6322_100_T20-60765_I-1 (3 of 177): binned read counts loaded from cache
#     6322_101_T20-60767_I-1 (4 of 177): binned read counts loaded from cache
#     6322_102_T20-60768_I-1 (5 of 177): binned read counts loaded from cache
#     6322_103_T20-60769_I-1 (6 of 177): binned read counts loaded from cache
#     6322_104_T20-60770_I-1 (7 of 177): binned read counts loaded from cache
#     6322_11_T20-60669_I-1 (8 of 177): binned read counts loaded from cache
#     6322_12_T20-60672_I-1 (9 of 177): binned read counts loaded from cache
#     6322_13_T20-60676_I-1 (10 of 177): binned read counts loaded from cache
#     6322_14_T20-60680_I-1 (11 of 177): binned read counts loaded from cache
#     6322_15_T20-60652_I-1 (12 of 177): binned read counts loaded from cache
#     6322_16_T20-60654_I-1 (13 of 177): binned read counts loaded from cache
#     6322_17_T20-60656_I-1 (14 of 177): binned read counts loaded from cache
#     6322_18_T20-60657_I-1 (15 of 177): binned read counts loaded from cache
#     6322_19_T20-60658_I-1 (16 of 177): binned read counts loaded from cache
#     6322_2_T20-60641_I-1 (17 of 177): binned read counts loaded from cache
#     6322_20_T20-60661_I-1 (18 of 177): binned read counts loaded from cache
#     6322_21_T20-60662_I-1 (19 of 177): binned read counts loaded from cache
#     6322_22_T20-60663_I-1 (20 of 177): binned read counts loaded from cache
#     6322_23_T20-60666_I-1 (21 of 177): binned read counts loaded from cache
#     6322_24_T20-60667_I-1 (22 of 177): binned read counts loaded from cache
#     6322_25_T20-60668_I-1 (23 of 177): binned read counts loaded from cache
#     6322_26_T20-60702_I-1 (24 of 177): binned read counts loaded from cache
#     6322_27_T20-60704_I-1 (25 of 177): binned read counts loaded from cache
#     6322_28_T20-60706_I-1 (26 of 177): binned read counts loaded from cache
#     6322_29_T20-60708_I-1 (27 of 177): binned read counts loaded from cache
#     6322_3_T20-60644_I-1 (28 of 177): binned read counts loaded from cache
#     6322_30_T20-60718_I-1 (29 of 177): binned read counts loaded from cache
#     6322_31_T20-60671_I-1 (30 of 177): binned read counts loaded from cache
#     6322_33_T20-60674_I-1 (31 of 177): binned read counts loaded from cache
#     6322_34_T20-60675_I-1 (32 of 177): binned read counts loaded from cache
#     6322_35_T20-60677_I-1 (33 of 177): binned read counts loaded from cache
#     6322_36_T20-60678_I-1 (34 of 177): binned read counts loaded from cache
#     6322_38_T20-60686_I-1 (35 of 177): binned read counts loaded from cache
#     6322_39_T20-60688_I-1 (36 of 177): binned read counts loaded from cache
#     6322_4_T20-60645_I-1 (37 of 177): binned read counts loaded from cache
#     6322_40_T20-60690_I-1 (38 of 177): binned read counts loaded from cache
#     6322_43_T20-60694_I-1 (39 of 177): binned read counts loaded from cache
#     6322_44_T20-60697_I-1 (40 of 177): binned read counts loaded from cache
#     6322_45_T20-60703_I-1 (41 of 177): binned read counts loaded from cache
#     6322_46_T20-60705_I-1 (42 of 177): binned read counts loaded from cache
#     6322_48_T20-60710_I-1 (43 of 177): binned read counts loaded from cache
#     6322_49_T20-60711_I-1 (44 of 177): binned read counts loaded from cache
#     6322_5_T20-60647_I-1 (45 of 177): binned read counts loaded from cache
#     6322_50_T20-60714_I-1 (46 of 177): binned read counts loaded from cache
#     6322_51_T20-60715_I-1 (47 of 177): binned read counts loaded from cache
#     6322_52_T20-60717_I-1 (48 of 177): binned read counts loaded from cache
#     6322_53_T20-60723_I-1 (49 of 177): binned read counts loaded from cache
#     6322_54_T20-60724_I-1 (50 of 177): binned read counts loaded from cache
#     6322_55_T20-60709_I-1 (51 of 177): binned read counts loaded from cache
#     6322_56_T20-60712_I-1 (52 of 177): binned read counts loaded from cache
#     6322_57_T20-60713_I-1 (53 of 177): binned read counts loaded from cache
#     6322_58_T20-60719_I-1 (54 of 177): binned read counts loaded from cache
#     6322_59_T20-60720_I-1 (55 of 177): binned read counts loaded from cache
#     6322_6_T20-60653_I-1 (56 of 177): binned read counts loaded from cache
#     6322_60_T20-60721_I-1 (57 of 177): binned read counts loaded from cache
#     6322_61_T20-60722_I-1 (58 of 177): binned read counts loaded from cache
#     6322_62_T20-60728_I-1 (59 of 177): binned read counts loaded from cache
#     6322_63_T20-60734_I-1 (60 of 177): binned read counts loaded from cache
#     6322_64_T20-60743_I-1 (61 of 177): binned read counts loaded from cache
#     6322_65_T20-60745_I-1 (62 of 177): binned read counts loaded from cache
#     6322_66_T20-60746_I-1 (63 of 177): binned read counts loaded from cache
#     6322_67_T20-60755_I-1 (64 of 177): binned read counts loaded from cache
#     6322_68_T20-60756_I-1 (65 of 177): binned read counts loaded from cache
#     6322_69_T20-60760_I-1 (66 of 177): binned read counts loaded from cache
#     6322_7_T20-60655_I-1 (67 of 177): binned read counts loaded from cache
#     6322_70_T20-60725_I-1 (68 of 177): binned read counts loaded from cache
#     6322_71_T20-60726_I-1 (69 of 177): binned read counts loaded from cache
#     6322_72_T20-60727_I-1 (70 of 177): binned read counts loaded from cache
#     6322_73_T20-60729_I-1 (71 of 177): binned read counts loaded from cache
#     6322_74_T20-60733_I-1 (72 of 177): binned read counts loaded from cache
#     6322_75_T20-60738_I-1 (73 of 177): binned read counts loaded from cache
#     6322_76_T20-60747_I-1 (74 of 177): binned read counts loaded from cache
#     6322_77_T20-60748_I-1 (75 of 177): binned read counts loaded from cache
#     6322_78_T20-60750_I-1 (76 of 177): binned read counts loaded from cache
#     6322_79_T20-60752_I-1 (77 of 177): binned read counts loaded from cache
#     6322_8_T20-60659_I-1 (78 of 177): binned read counts loaded from cache
#     6322_80_T20-60753_I-1 (79 of 177): binned read counts loaded from cache
#     6322_81_T20-60754_I-1 (80 of 177): binned read counts loaded from cache
#     6322_82_T20-60757_I-1 (81 of 177): binned read counts loaded from cache
#     6322_83_T20-60758_I-1 (82 of 177): binned read counts loaded from cache
#     6322_84_T20-60759_I-1 (83 of 177): binned read counts loaded from cache
#     6322_85_T20-60764_I-1 (84 of 177): binned read counts loaded from cache
#     6322_86_T20-60665_I-1 (85 of 177): binned read counts loaded from cache
#     6322_87_T20-60665_I-2 (86 of 177): binned read counts loaded from cache
#     6322_88_T20-60700_I-1 (87 of 177): binned read counts loaded from cache
#     6322_89_T20-60744_I-1 (88 of 177): binned read counts loaded from cache
#     6322_9_T20-60660_I-1 (89 of 177): binned read counts loaded from cache
#     6322_90_T20-60744_I-2 (90 of 177): binned read counts loaded from cache
#     6322_91_T20-60761_I-1 (91 of 177): binned read counts loaded from cache
#     6322_92_T20-60762_I-1 (92 of 177): binned read counts loaded from cache
#     6322_93_T20-60763_I-1 (93 of 177): binned read counts loaded from cache
#     6322_94_T20-60766_I-1 (94 of 177): binned read counts loaded from cache
#     6322_95_T20-60444_I-1 (95 of 177): binned read counts loaded from cache
#     6322_96_T20-60453_I-1 (96 of 177): binned read counts loaded from cache
#     6322_97_T20-60598_I-1 (97 of 177): binned read counts loaded from cache
#     6322_98_T20-60598_I-2 (98 of 177): binned read counts loaded from cache
#     6322_99_T20-60626_I-1 (99 of 177): binned read counts loaded from cache
#     RUN1097_6309_1_T20-60470_I-1_TAACTTGGTC-GTCGTGAATC_S2 (100 of 177): binned read counts loaded from cache
#     RUN1097_6309_10_T20-60558_I-1_TCCAACTGAA-TGTCCGTAGG_S11 (101 of 177): binned read counts loaded from cache
#     RUN1097_6309_11_T20-60564_I-1_ATTCGGCTTA-TTAACGTCCG_S17 (102 of 177): binned read counts loaded from cache
#     RUN1097_6309_12_T20-60570_I-1_TATGGCAAGC-AACAGCAATG_S18 (103 of 177): binned read counts loaded from cache
#     RUN1097_6309_13_T20-60572_I-1_CCTAAGCTGA-CGTCGCATCT_S19 (104 of 177): binned read counts loaded from cache
#     RUN1097_6309_14_T20-60580_I-1_GCCACCTAGT-TGCGATGTAT_S20 (105 of 177): binned read counts loaded from cache
#     RUN1097_6309_15_T20-60475_I-1_AGTATCCGAT-TATTGCGCTA_S16 (106 of 177): binned read counts loaded from cache
#     RUN1097_6309_16_T20-60476_I-1_CCTCGTTGGA-GACTGCGTTA_S23 (107 of 177): binned read counts loaded from cache
#     RUN1097_6309_17_T20-60596_I-1_CGACCTTAAT-GCTCTTAGGT_S24 (108 of 177): binned read counts loaded from cache
#     RUN1097_6309_18_T20-60597_I-1_GAACCGCATT-CATTATGCCT_S25 (109 of 177): binned read counts loaded from cache
#     RUN1097_6309_19_T20-60600_I-1_CGCGGTATCT-ATTACCGATC_S26 (110 of 177): binned read counts loaded from cache
#     RUN1097_6309_2_T20-60501_I-1_TCGAACACGA-GCGAGGTTCT_S5 (111 of 177): binned read counts loaded from cache
#     RUN1097_6309_20_T20-60603_I-1_ACTCCGAAGC-TCCGTGTTGC_S27 (112 of 177): binned read counts loaded from cache
#     RUN1097_6309_21_T20-60608_I-1_CGATGTCTTG-CCGAACGTTC_S22 (113 of 177): binned read counts loaded from cache
#     RUN1097_6309_22_T20-60609_I-1_CTCCGCCATA-GCGTTCAGCA_S30 (114 of 177): binned read counts loaded from cache
#     RUN1097_6309_23_T20-60611_I-1_AACGAAGATC-TGTGGTCTAA_S31 (115 of 177): binned read counts loaded from cache
#     RUN1097_6309_24_T20-60612_I-1_AATAGGTAGG-TGGCTTATGG_S32 (116 of 177): binned read counts loaded from cache
#     RUN1097_6309_25_T20-60613_I-1_ATGTTGCCAC-TAGAAGCCAT_S33 (117 of 177): binned read counts loaded from cache
#     RUN1097_6309_26_T20-60615_I-1_ACAACAGGCT-TCCACTGTTG_S34 (118 of 177): binned read counts loaded from cache
#     RUN1097_6309_70_T20-60599_I-1_TCAGCATCTA-CCAGTGTACG_S61 (167 of 177): binned read counts loaded from cache
#     RUN1097_6309_71_T20-60605_I-1_GAGCAGCTTG-TGCCAGTATT_S72 (168 of 177): binned read counts loaded from cache
#     RUN1097_6309_72_T20-60606_I-1_CGGAACACAA-AACTCTACCG_S66 (169 of 177): binned read counts loaded from cache
#     RUN1097_6309_73_T20-60610_I-1_CTTGCTATTC-TAGAGTCACG_S73 (170 of 177): binned read counts loaded from cache
#     RUN1097_6309_74_T20-60617_I-1_CCACAGCCTT-GCTATTGAAG_S74 (171 of 177): binned read counts loaded from cache
#     RUN1097_6309_75_T20-60621_I-1_TCAGTTCGAT-CTGAGTCCTT_S75 (172 of 177): binned read counts loaded from cache
#     RUN1097_6309_76_T20-60625_I-1_AGCAATTCAC-TCATCGTCTG_S76 (173 of 177): binned read counts loaded from cache
#     RUN1097_6309_77_T20-60627_I-1_CCTCTATAGA-GTACTTCCAA_S77 (174 of 177): binned read counts loaded from cache
#     RUN1097_6309_78_T20-60637_I-1_GTTGCATCAA-GTTGATGCGA_S78 (175 of 177): binned read counts loaded from cache
#     RUN1097_6309_8_T20-60541_I-1_GCCAACAGAC-CGTTCACGTT_S13 (176 of 177): binned read counts loaded from cache
#     RUN1097_6309_9_T20-60546_I-1_ATAAGCGGAG-CTGTTCTACG_S14 (177 of 177): binned read counts loaded from cache
# 30,894	total bins
# 28,760	of which in selected chromosomes
# 27,679	of which with reference sequence
# 25,147	final bins
# Calculating correction for GC content and mappability
#     Calculating fit for sample 6322_1_T20-60638_I-1 (1 of 177) ...
#     Calculating fit for sample 6322_10_T20-60664_I-1 (2 of 177) ...
#     Calculating fit for sample 6322_100_T20-60765_I-1 (3 of 177) ...
#     Calculating fit for sample 6322_101_T20-60767_I-1 (4 of 177) ...
#     Calculating fit for sample 6322_102_T20-60768_I-1 (5 of 177) ...
#     Calculating fit for sample 6322_103_T20-60769_I-1 (6 of 177) ...
#     Calculating fit for sample 6322_104_T20-60770_I-1 (7 of 177) ...
#     Calculating fit for sample 6322_11_T20-60669_I-1 (8 of 177) ...
#     Calculating fit for sample 6322_12_T20-60672_I-1 (9 of 177) ...
#     Calculating fit for sample 6322_13_T20-60676_I-1 (10 of 177) ...
#     Calculating fit for sample 6322_14_T20-60680_I-1 (11 of 177) ...
#     Calculating fit for sample 6322_15_T20-60652_I-1 (12 of 177) ...
#     Calculating fit for sample 6322_16_T20-60654_I-1 (13 of 177) ...
#     Calculating fit for sample 6322_17_T20-60656_I-1 (14 of 177) ...
#     Calculating fit for sample 6322_18_T20-60657_I-1 (15 of 177) ...
#     Calculating fit for sample 6322_19_T20-60658_I-1 (16 of 177) ...
#     Calculating fit for sample 6322_2_T20-60641_I-1 (17 of 177) ...
#     Calculating fit for sample 6322_20_T20-60661_I-1 (18 of 177) ...
#     Calculating fit for sample 6322_21_T20-60662_I-1 (19 of 177) ...
#     Calculating fit for sample 6322_22_T20-60663_I-1 (20 of 177) ...
#     Calculating fit for sample 6322_23_T20-60666_I-1 (21 of 177) ...
#     Calculating fit for sample 6322_24_T20-60667_I-1 (22 of 177) ...
#     Calculating fit for sample 6322_25_T20-60668_I-1 (23 of 177) ...
#     Calculating fit for sample 6322_26_T20-60702_I-1 (24 of 177) ...
#     Calculating fit for sample 6322_27_T20-60704_I-1 (25 of 177) ...
#     Calculating fit for sample 6322_28_T20-60706_I-1 (26 of 177) ...
#     Calculating fit for sample 6322_29_T20-60708_I-1 (27 of 177) ...
#     Calculating fit for sample 6322_3_T20-60644_I-1 (28 of 177) ...
#     Calculating fit for sample 6322_30_T20-60718_I-1 (29 of 177) ...
#     Calculating fit for sample 6322_31_T20-60671_I-1 (30 of 177) ...
#     Calculating fit for sample 6322_33_T20-60674_I-1 (31 of 177) ...
#     Calculating fit for sample 6322_34_T20-60675_I-1 (32 of 177) ...
#     Calculating fit for sample 6322_35_T20-60677_I-1 (33 of 177) ...
#     Calculating fit for sample 6322_36_T20-60678_I-1 (34 of 177) ...
#     Calculating fit for sample 6322_38_T20-60686_I-1 (35 of 177) ...
#     Calculating fit for sample 6322_39_T20-60688_I-1 (36 of 177) ...
#     Calculating fit for sample 6322_4_T20-60645_I-1 (37 of 177) ...
#     Calculating fit for sample 6322_40_T20-60690_I-1 (38 of 177) ...
#     Calculating fit for sample 6322_43_T20-60694_I-1 (39 of 177) ...
#     Calculating fit for sample 6322_44_T20-60697_I-1 (40 of 177) ...
#     Calculating fit for sample 6322_45_T20-60703_I-1 (41 of 177) ...
#     Calculating fit for sample 6322_46_T20-60705_I-1 (42 of 177) ...
#     Calculating fit for sample 6322_48_T20-60710_I-1 (43 of 177) ...
#     Calculating fit for sample 6322_49_T20-60711_I-1 (44 of 177) ...
#     Calculating fit for sample 6322_5_T20-60647_I-1 (45 of 177) ...
#     Calculating fit for sample 6322_50_T20-60714_I-1 (46 of 177) ...
#     Calculating fit for sample 6322_51_T20-60715_I-1 (47 of 177) ...
#     Calculating fit for sample 6322_52_T20-60717_I-1 (48 of 177) ...
#     Calculating fit for sample 6322_53_T20-60723_I-1 (49 of 177) ...
#     Calculating fit for sample 6322_54_T20-60724_I-1 (50 of 177) ...
#     Calculating fit for sample 6322_55_T20-60709_I-1 (51 of 177) ...
#     Calculating fit for sample 6322_56_T20-60712_I-1 (52 of 177) ...
#     Calculating fit for sample 6322_57_T20-60713_I-1 (53 of 177) ...
#     Calculating fit for sample 6322_58_T20-60719_I-1 (54 of 177) ...
#     Calculating fit for sample 6322_59_T20-60720_I-1 (55 of 177) ...
#     Calculating fit for sample 6322_6_T20-60653_I-1 (56 of 177) ...
#     Calculating fit for sample 6322_60_T20-60721_I-1 (57 of 177) ...
#     Calculating fit for sample 6322_61_T20-60722_I-1 (58 of 177) ...
#     Calculating fit for sample 6322_62_T20-60728_I-1 (59 of 177) ...
#     Calculating fit for sample 6322_63_T20-60734_I-1 (60 of 177) ...
#     Calculating fit for sample 6322_64_T20-60743_I-1 (61 of 177) ...
#     Calculating fit for sample 6322_65_T20-60745_I-1 (62 of 177) ...
#     Calculating fit for sample 6322_66_T20-60746_I-1 (63 of 177) ...
#     Calculating fit for sample 6322_67_T20-60755_I-1 (64 of 177) ...
#     Calculating fit for sample 6322_68_T20-60756_I-1 (65 of 177) ...
#     Calculating fit for sample 6322_69_T20-60760_I-1 (66 of 177) ...
#     Calculating fit for sample 6322_7_T20-60655_I-1 (67 of 177) ...
#     Calculating fit for sample 6322_70_T20-60725_I-1 (68 of 177) ...
#     Calculating fit for sample 6322_71_T20-60726_I-1 (69 of 177) ...
#     Calculating fit for sample 6322_72_T20-60727_I-1 (70 of 177) ...
#     Calculating fit for sample 6322_73_T20-60729_I-1 (71 of 177) ...
#     Calculating fit for sample 6322_74_T20-60733_I-1 (72 of 177) ...
#     Calculating fit for sample 6322_75_T20-60738_I-1 (73 of 177) ...
#     Calculating fit for sample 6322_76_T20-60747_I-1 (74 of 177) ...
#     Calculating fit for sample 6322_77_T20-60748_I-1 (75 of 177) ...
#     Calculating fit for sample 6322_78_T20-60750_I-1 (76 of 177) ...
#     Calculating fit for sample 6322_79_T20-60752_I-1 (77 of 177) ...
#     Calculating fit for sample 6322_8_T20-60659_I-1 (78 of 177) ...
#     Calculating fit for sample 6322_80_T20-60753_I-1 (79 of 177) ...
#     Calculating fit for sample 6322_81_T20-60754_I-1 (80 of 177) ...
#     Calculating fit for sample 6322_82_T20-60757_I-1 (81 of 177) ...
#     Calculating fit for sample 6322_83_T20-60758_I-1 (82 of 177) ...
#     Calculating fit for sample 6322_84_T20-60759_I-1 (83 of 177) ...
#     Calculating fit for sample 6322_85_T20-60764_I-1 (84 of 177) ...
#     Calculating fit for sample 6322_86_T20-60665_I-1 (85 of 177) ...
#     Calculating fit for sample 6322_87_T20-60665_I-2 (86 of 177) ...
#     Calculating fit for sample 6322_88_T20-60700_I-1 (87 of 177) ...
#     Calculating fit for sample 6322_89_T20-60744_I-1 (88 of 177) ...
#     Calculating fit for sample 6322_9_T20-60660_I-1 (89 of 177) ...
#     Calculating fit for sample 6322_90_T20-60744_I-2 (90 of 177) ...
#     Calculating fit for sample 6322_91_T20-60761_I-1 (91 of 177) ...
#     Calculating fit for sample 6322_92_T20-60762_I-1 (92 of 177) ...
#     Calculating fit for sample 6322_93_T20-60763_I-1 (93 of 177) ...
#     Calculating fit for sample 6322_94_T20-60766_I-1 (94 of 177) ...
#     Calculating fit for sample 6322_95_T20-60444_I-1 (95 of 177) ...
#     Calculating fit for sample 6322_96_T20-60453_I-1 (96 of 177) ...
#     Calculating fit for sample 6322_97_T20-60598_I-1 (97 of 177) ...
#     Calculating fit for sample 6322_98_T20-60598_I-2 (98 of 177) ...
#     Calculating fit for sample 6322_99_T20-60626_I-1 (99 of 177) ...
#     Calculating fit for sample RUN1097_6309_1_T20-60470_I-1_TAACTTGGTC-GTCGTGAATC_S2 (100 of 177) ...
#     Calculating fit for sample RUN1097_6309_10_T20-60558_I-1_TCCAACTGAA-TGTCCGTAGG_S11 (101 of 177) ...
#     Calculating fit for sample RUN1097_6309_11_T20-60564_I-1_ATTCGGCTTA-TTAACGTCCG_S17 (102 of 177) ...
# EM algorithm done ...
#
# Computing posterior probabilities for all segments ...
#
# Total time:17minutes
#
# Adjusting segmented data for cellularity ...
#
# Cellularity sample1: 1
#
# Cellularity sample2: 1
#
# Cellularity sample3: 1
#
# Cellularity sample4: 1
#
# Cellularity sample5: 1
#
# Cellularity sample6: 1
#
# Cellularity sample7: 1
#
# Cellularity sample8: 1
#
# Cellularity sample9: 1
#
# Cellularity sample10: 1
#
# Cellularity sample11: 1
#
# Cellularity sample12: 1
#
# Cellularity sample13: 1
#
# Cellularity sample14: 1
#
# Cellularity sample15: 1
#
# Cellularity sample16: 1
#
# Cellularity sample17: 1
#
# Cellularity sample18: 1
#
# Cellularity sample19: 1
#
# Cellularity sample20: 1
#
# Cellularity sample21: 1
#
# Cellularity sample22: 1
#
# Cellularity sample23: 1
#
# Cellularity sample24: 1
#
# Cellularity sample25: 1
#
# Cellularity sample26: 1
#
# Cellularity sample27: 1
#
# Cellularity sample28: 1
#
# Cellularity sample29: 1
#
# Cellularity sample30: 1
#
# Cellularity sample31: 1
#
# Cellularity sample32: 1
#
# Cellularity sample33: 1
#
# Cellularity sample34: 1
#
# Cellularity sample35: 1
#
# Cellularity sample36: 1
#
# Cellularity sample37: 1
#
# Cellularity sample38: 1
#
# Cellularity sample39: 1
#
# Cellularity sample40: 1
#
# Cellularity sample41: 1
#
# Cellularity sample42: 1
#
# Cellularity sample43: 1
#
# Cellularity sample44: 1
#
# Cellularity sample45: 1
#
# Cellularity sample46: 1
#
# Cellularity sample47: 1
#
# Cellularity sample48: 1
#
# Cellularity sample49: 1
#
# Cellularity sample50: 1
#
# Cellularity sample51: 1
#
# Cellularity sample52: 1
#
# Cellularity sample53: 1
#
# Cellularity sample54: 1
#
# Cellularity sample55: 1
#
# Cellularity sample56: 1
#
# Cellularity sample57: 1
#
# Cellularity sample58: 1
#
# Cellularity sample59: 1
#
# Cellularity sample60: 1
#
# Cellularity sample61: 1
#
# Cellularity sample62: 1
#
# Cellularity sample63: 1
#
# Cellularity sample64: 1
#
# Cellularity sample65: 1
#
# Cellularity sample66: 1
#
# Cellularity sample67: 1
#
# Cellularity sample68: 1
#
# Cellularity sample69: 1
#
# Cellularity sample70: 1
#
# Cellularity sample71: 1
#
# Cellularity sample72: 1
#
# Cellularity sample73: 1
#
# Cellularity sample74: 1
#
# Cellularity sample75: 1
#
# Cellularity sample76: 1
#
# Cellularity sample77: 1
#
# Cellularity sample78: 1
#
# Cellularity sample79: 1
#
# Cellularity sample80: 1
#
# Cellularity sample81: 1
#
# Cellularity sample82: 1
#
# Cellularity sample83: 1
#
# Cellularity sample84: 1
#
# Cellularity sample85: 1
#
# Cellularity sample86: 1
#
# Cellularity sample87: 1
#
# Cellularity sample88: 1
#
# Cellularity sample89: 1
#
# Cellularity sample90: 1
#
# Cellularity sample91: 1
#
# Cellularity sample92: 1
#
# Cellularity sample93: 1
#
# Cellularity sample94: 1
#
# Cellularity sample95: 1
#
# Cellularity sample96: 1
#
# Cellularity sample97: 1
#
# Cellularity sample98: 1
#
# Cellularity sample99: 1
#
# Cellularity sample100: 1
#
# Cellularity sample101: 1
#
# Cellularity sample102: 1
#
# Cellularity sample103: 1
#
# Cellularity sample104: 1
#
# Cellularity sample105: 1
#
# Cellularity sample106: 1
#
# Cellularity sample107: 1
#
# Cellularity sample108: 1
#
# Cellularity sample109: 1
#
# Cellularity sample110: 1
#
# Cellularity sample111: 1
#
# Cellularity sample112: 1
#
# Cellularity sample113: 1
#
# Cellularity sample114: 1
#
# Cellularity sample115: 1
#
# Cellularity sample116: 1
#
# Cellularity sample117: 1
#
# Cellularity sample118: 1
#
# Cellularity sample119: 1
#
# Cellularity sample120: 1
#
# Cellularity sample121: 1
#
# Cellularity sample122: 1
#
# Cellularity sample123: 1
#
# Cellularity sample124: 1
#
# Cellularity sample125: 1
#
# Cellularity sample126: 1
#
# Cellularity sample127: 1
#
# Cellularity sample128: 1
#
# Cellularity sample129: 1
#
# Cellularity sample130: 1
#
# Cellularity sample131: 1
#
# Cellularity sample132: 1
#
# Cellularity sample133: 1
#
# Cellularity sample134: 1
#
# Cellularity sample135: 1
#
# Cellularity sample136: 1
#
# Cellularity sample137: 1
#
# Cellularity sample138: 1
#
# Cellularity sample139: 1
#
# Cellularity sample140: 1
#
# Cellularity sample141: 1
#
# Cellularity sample142: 1
#
# Cellularity sample143: 1
#
# Cellularity sample144: 1
#
# Cellularity sample145: 1
#
# Cellularity sample146: 1
#
# Cellularity sample147: 1
#
# Cellularity sample148: 1
#
# Cellularity sample149: 1
#
# Cellularity sample150: 1
#
# Cellularity sample151: 1
#
# Cellularity sample152: 1
#
# Cellularity sample153: 1
#
# Cellularity sample154: 1
#
# Cellularity sample155: 1
#
# Cellularity sample156: 1
#
# Cellularity sample157: 1
#
# Cellularity sample158: 1
#
# Cellularity sample159: 1
#
# Cellularity sample160: 1
#
# Cellularity sample161: 1
#
# Cellularity sample162: 1
#
# Cellularity sample163: 1
#
# Cellularity sample164: 1
# Cellularity sample165: 1
#
# Cellularity sample166: 1
#
# Cellularity sample167: 1
#
# Cellularity sample168: 1
#
# Cellularity sample169: 1
#
# Cellularity sample170: 1
#
# Cellularity sample171: 1
#
# Cellularity sample172: 1
#
# Cellularity sample173: 1
#
# Cellularity sample174: 1
#
# Cellularity sample175: 1
#
# Cellularity sample176: 1
#
# Cellularity sample177: 1
#
# Adjusting normalized data for cellularity ...
#
# Cellularity sample1: 1
#
# Cellularity sample2: 1
#
# Cellularity sample3: 1
#
# Cellularity sample4: 1
#
# Cellularity sample5: 1
#
# Cellularity sample6: 1
#
# Cellularity sample7: 1
#
# Cellularity sample8: 1
#
# Cellularity sample9: 1
#
# Cellularity sample10: 1
#
# Cellularity sample11: 1
#
# Cellularity sample12: 1
#
# Cellularity sample13: 1
#
# Cellularity sample14: 1
#
# Cellularity sample15: 1
#
# Cellularity sample16: 1
#
# Cellularity sample17: 1
#
# Cellularity sample18: 1
#
# Cellularity sample19: 1
#
# Cellularity sample20: 1
#
# Cellularity sample21: 1
#
# Cellularity sample22: 1
#
# Cellularity sample23: 1
#
# Cellularity sample24: 1
#
# Cellularity sample25: 1
#
# Cellularity sample26: 1
#
# Cellularity sample27: 1
#
# Cellularity sample28: 1
#
# Cellularity sample29: 1
#
# Cellularity sample30: 1
#
# Cellularity sample31: 1
#
# Cellularity sample32: 1
#
# Cellularity sample33: 1
#
# Cellularity sample34: 1
#
# Cellularity sample35: 1
#
# Cellularity sample36: 1
#
# Cellularity sample37: 1
#
# Cellularity sample38: 1
#
# Cellularity sample39: 1
#
# Cellularity sample40: 1
#
# Cellularity sample41: 1
#
# Cellularity sample42: 1
#
# Cellularity sample43: 1
#
# Cellularity sample44: 1
#
# Cellularity sample45: 1
#
# Cellularity sample46: 1
#
# Cellularity sample47: 1
#
# Cellularity sample48: 1
#
# Cellularity sample49: 1
#
# Cellularity sample50: 1
#
# Cellularity sample51: 1
#
# Cellularity sample52: 1
#
# Cellularity sample53: 1
#
# Cellularity sample54: 1
#
# Cellularity sample55: 1
#
# Cellularity sample56: 1
#
# Cellularity sample57: 1
#
# Cellularity sample58: 1
#
# Cellularity sample59: 1
#
# Cellularity sample60: 1
#
# Cellularity sample61: 1
#
# Cellularity sample62: 1
#
# Cellularity sample63: 1
#
# Cellularity sample64: 1
#
# Cellularity sample65: 1
#
# Cellularity sample66: 1
#
# Cellularity sample67: 1
#
# Cellularity sample68: 1
#
# Cellularity sample69: 1
#
# Cellularity sample70: 1
#
# Cellularity sample71: 1
#
# Cellularity sample72: 1
#
# Cellularity sample73: 1
#
# Cellularity sample74: 1
#
# Cellularity sample75: 1
#
# Cellularity sample76: 1
#
# Cellularity sample77: 1
#
# Cellularity sample78: 1
#
# Cellularity sample79: 1
#
# Cellularity sample80: 1
#
# Cellularity sample81: 1
#
# Cellularity sample82: 1
#
# Cellularity sample83: 1
#
# Cellularity sample84: 1
#
# Cellularity sample85: 1
#
# Cellularity sample86: 1
#
# Cellularity sample87: 1
#
# Cellularity sample88: 1
#
# Cellularity sample89: 1
#
# Cellularity sample90: 1
#
# Cellularity sample91: 1
#
# Cellularity sample92: 1
#
# Cellularity sample93: 1
#
# Cellularity sample94: 1
#
# Cellularity sample95: 1
#
# Cellularity sample96: 1
#
# Cellularity sample97: 1
#
# Cellularity sample98: 1
#
# Cellularity sample99: 1
#
# Cellularity sample100: 1
#
# Cellularity sample101: 1
#
# Cellularity sample102: 1
#
# Cellularity sample103: 1
#
# Cellularity sample104: 1
#
# Cellularity sample105: 1
#
# Cellularity sample106: 1
#
# Cellularity sample107: 1
#
# Cellularity sample108: 1
#
# Cellularity sample109: 1
#
# Cellularity sample110: 1
#
# Cellularity sample111: 1
#
# Cellularity sample112: 1
#
# Cellularity sample113: 1
#
# Cellularity sample114: 1
#
# Cellularity sample115: 1
#
# Cellularity sample116: 1
#
# Cellularity sample117: 1
#
# Cellularity sample118: 1
#
# Cellularity sample119: 1
#
# Cellularity sample120: 1
#
# Cellularity sample121: 1
#
# Cellularity sample122: 1
#
# Cellularity sample123: 1
#
# Cellularity sample124: 1
#
# Cellularity sample125: 1
#
# Cellularity sample126: 1
#
# Cellularity sample127: 1
#
# Cellularity sample128: 1
#
# Cellularity sample129: 1
#
# Cellularity sample130: 1
#
# Cellularity sample131: 1
#
# Cellularity sample132: 1
#
# Cellularity sample133: 1
#
# Cellularity sample134: 1
#
# Cellularity sample135: 1
#
# Cellularity sample136: 1
#
# Cellularity sample137: 1
#
# Cellularity sample138: 1
#
# Cellularity sample139: 1
#
# Cellularity sample140: 1
#
# Cellularity sample141: 1
#
# Cellularity sample142: 1
#
# Cellularity sample143: 1
#
# Cellularity sample144: 1
#
# Cellularity sample145: 1
#
# Cellularity sample146: 1
#
# Cellularity sample147: 1
#
# Cellularity sample148: 1
#
# Cellularity sample149: 1
#
# Cellularity sample150: 1
#
# Cellularity sample151: 1
#
# Cellularity sample152: 1
#
# Cellularity sample153: 1
#
# Cellularity sample154: 1
#
# Cellularity sample155: 1
#
# Cellularity sample156: 1
#
# Cellularity sample157: 1
#
# Cellularity sample158: 1
#
# Cellularity sample159: 1
#
# Cellularity sample160: 1
#
# Cellularity sample161: 1
#
# Cellularity sample162: 1
#
# Cellularity sample163: 1
#
# Cellularity sample164: 1
#
# Cellularity sample165: 1
#
# Cellularity sample166: 1
#
# Cellularity sample167: 1
#
# Cellularity sample168: 1
#
# Cellularity sample169: 1
#
# Cellularity sample170: 1
#
# Cellularity sample171: 1
#
# Cellularity sample172: 1
#
# Cellularity sample173: 1
#
# Cellularity sample174: 1
#
# Cellularity sample175: 1
#
# Cellularity sample176: 1
#
# Cellularity sample177: 1
#
# 1
# 386525969632382206.5531.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# 386527769758125206.5532.37549529111456781403.2850.47549529132621890403.21011.9
# ...
# Plotting sample 6322_58_T20-60719_I-1 (4,418,926 reads) (1 of 1) ...
# Plotting sample 6322_59_T20-60720_I-1 (4,878,704 reads) (1 of 1) ...
# Plotting sample 6322_6_T20-60653_I-1 (3,577,353 reads) (1 of 1) ...
# Plotting sample 6322_60_T20-60721_I-1 (4,772,046 reads) (1 of 1) ...
# Plotting sample 6322_61_T20-60722_I-1 (4,590,370 reads) (1 of 1) ...
# Plotting sample 6322_62_T20-60728_I-1 (5,530,619 reads) (1 of 1) ...
# Plotting sample 6322_63_T20-60734_I-1 (5,393,294 reads) (1 of 1) ...
reads) (1 of 1) ...
# Plotting sample RUN1097_6309_71_T20-60605_I-1_GAGCAGCTTG-TGCCAGTATT_S72 (4,577,653 reads) (1 of 1) ...
# Plotting sample RUN1097_6309_72_T20-60606_I-1_CGGAACACAA-AACTCTACCG_S66 (4,902,901 reads) (1 of 1) ...
# Plotting sample RUN1097_6309_73_T20-60610_I-1_CTTGCTATTC-TAGAGTCACG_S73 (5,355,983 reads) (1 of 1) ...
# Plotting sample RUN1097_6309_74_T20-60617_I-1_CCACAGCCTT-GCTATTGAAG_S74 (5,646,499 reads) (1 of 1) ...
# Plotting sample RUN1097_6309_75_T20-60621_I-1_TCAGTTCGAT-CTGAGTCCTT_S75 (7,014,474 reads) (1 of 1) ...
# Plotting sample RUN1097_6309_76_T20-60625_I-1_AGCAATTCAC-TCATCGTCTG_S76 (4,612,476 reads) (1 of 1) ...
# Plotting sample RUN1097_6309_77_T20-60627_I-1_CCTCTATAGA-GTACTTCCAA_S77 (5,962,826 reads) (1 of 1) ...
# Plotting sample RUN1097_6309_78_T20-60637_I-1_GTTGCATCAA-GTTGATGCGA_S78 (5,814,752 reads) (1 of 1) ...
# Plotting sample RUN1097_6309_8_T20-60541_I-1_GCCAACAGAC-CGTTCACGTT_S13 (5,817,910 reads) (1 of 1) ...
# Plotting sample RUN1097_6309_9_T20-60546_I-1_ATAAGCGGAG-CTGTTCTACG_S14 (5,054,885 reads) (1 of 1) ...
#   |..................................................                    |  72%
#   ordinary text without R code
#
#   |....................................................                  |  75%
# label: Stats (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#   |.......................................................               |  78%
#   ordinary text without R code
#
#   |.........................................................             |  81%
# label: cghregions (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#   |...........................................................           |  84%
#   ordinary text without R code
#
#   |.............................................................         |  88%
# label: segments (with options)
# List of 2
#  $ warning: logi FALSE
#  $ message: logi FALSE
#
#   |...............................................................       |  91%
#   ordinary text without R code
#
#   |..................................................................    |  94%
# label: TBL (with options)
# List of 2
#  $ warning: logi FALSE
#  $ message: logi FALSE
#
# Loading required package: CGHcall
# Loading required package: DNAcopy
# Loading required package: snowfall
# Loading required package: snow
#
# Attaching package: 'snow'
#
# The following objects are masked from 'package:BiocGenerics':
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, clusterSplit, parApply, parCapply,
#     parLapply, parRapply, parSapply
#
# The following objects are masked from 'package:parallel':
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, clusterSplit, makeCluster, parApply,
#     parCapply, parLapply, parRapply, parSapply, splitIndices,
#     stopCluster
#
#
# Attaching package: 'CGHcall'
#
# The following object is masked from 'package:BiocGenerics':
#
#     normalize
#
# Loading required package: GenomicRanges
# Loading required package: stats4
# Loading required package: S4Vectors
#
# Attaching package: 'S4Vectors'
#
# The following object is masked from 'package:future':
#
#     values
#
# The following object is masked from 'package:base':
#
#     expand.grid
#
# Loading required package: IRanges
#
# Attaching package: 'IRanges'
#
# The following object is masked _by_ '.GlobalEnv':
#
#     shift
#
# Loading required package: GenomeInfoDb
#
# Attaching package: 'GeneBreak'
#
# The following object is masked _by_ '.GlobalEnv':
#
#     sampleNames
#
# The following object is masked from 'package:CGHcall':
#
#     segmentData
#
# The following object is masked from 'package:Biobase':
#
#     sampleNames
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ tibble  3.1.1     ✔ purrr   0.3.4
# ✔ tidyr   1.1.3     ✔ dplyr   1.0.6
# ✔ readr   1.4.0     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::collapse()   masks IRanges::collapse()
# ✖ dplyr::combine()    masks Biobase::combine(), BiocGenerics::combine()
# ✖ tidyr::complete()   masks RCurl::complete()
# ✖ dplyr::desc()       masks IRanges::desc()
# ✖ tidyr::expand()     masks S4Vectors::expand()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::first()      masks S4Vectors::first()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ ggplot2::Position() masks BiocGenerics::Position(), base::Position()
# ✖ purrr::reduce()     masks GenomicRanges::reduce(), IRanges::reduce()
# ✖ dplyr::rename()     masks S4Vectors::rename()
# ✖ dplyr::select()     masks MASS::select()
# ✖ dplyr::slice()      masks IRanges::slice()
#   |....................................................................  |  97%
#   ordinary text without R code
#
#   |......................................................................| 100%
# label: unnamed-chunk-2
#
# output file: QDNASeq_hg38_IntEnd_btD_server100kb.knit.md
#
# /home/l.gonzalez/anaconda3/bin/pandoc +RTS -K512m -RTS QDNASeq_hg38_IntEnd_btD_server100kb.utf8.md --to html4 --from markdown+autolink_bare_uris+tex_math_single_backslash --output QDNASeq_hg38_IntEnd_btD_server100kb.html --lua-filter /DATA/home/l.gonzalez/R/x86_64-pc-linux-gnu-library/3.6/rmarkdown/rmarkdown/lua/pagebreak.lua --lua-filter /DATA/home/l.gonzalez/R/x86_64-pc-linux-gnu-library/3.6/rmarkdown/rmarkdown/lua/latex-div.lua --self-contained --variable bs3=TRUE --standalone --section-divs --template /DATA/home/l.gonzalez/R/x86_64-pc-linux-gnu-library/3.6/rmarkdown/rmd/h/default.html --no-highlight --variable highlightjs=1 --variable theme=bootstrap --include-in-header /tmp/RtmpKcXluV/rmarkdown-str10b79d41d0a55e.html --mathjax --variable 'mathjax-url:https://mathjax.rstudio.com/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML'
#
# Output created: QDNASeq_hg38_IntEnd_btD_server100kb.html
# There were 50 or more warnings (use warnings() to see the first 50)
# >
# >

# %%
## To run QDNAseq for the 30kb bins
# !R -e "rmarkdown::render('/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/qdnaseq_out/QDNASeq_hg38_oldOrganoids_30kb.Rmd')"
# Out:
# R version 3.6.3 (2020-02-29) -- "Holding the Windsock"
# Copyright (C) 2020 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
#   Natural language support but running in an English locale
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# > rmarkdown::render('/DATA/share/pipelines/lgleon/organoids_rawdata/DNA/old_organoids/qdnaseq_out/QDNASeq_hg38_oldOrganoids_30kb.Rmd')
#
#
# processing file: QDNASeq_hg38_oldOrganoids_30kb.Rmd
#   |..                                                                    |   3%
#   ordinary text without R code
#
#   |....                                                                  |   6%
# label: unnamed-chunk-1 (with options)
# List of 1
#  $ include: logi FALSE
#
#   |.......                                                               |   9%
#   ordinary text without R code
#
#   |.........                                                             |  12%
# label: setup (with options)
# List of 1
#  $ include: logi FALSE
#
#   |...........                                                           |  16%
#   ordinary text without R code
#
#   |.............                                                         |  19%
# label: functions (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#   |...............                                                       |  22%
#   ordinary text without R code
#
#   |..................                                                    |  25%
# label: wd (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#   |....................                                                  |  28%
#   ordinary text without R code
#
#   |......................                                                |  31%
# label: paths (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#   |........................                                              |  34%
#   ordinary text without R code
#
#   |..........................                                            |  38%
# label: bam2smooth (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#     5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup (1 of 4): extracting reads ... saving in cache ... binning ... saving in cache ...
#     5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup (2 of 4): extracting reads ... saving in cache ... binning ... saving in cache ...
#     5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup (3 of 4): extracting reads ... saving in cache ... binning ... saving in cache ...
#     5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup (4 of 4): extracting reads ... saving in cache ... binning ... saving in cache ...
# 102,954	total bins
#  95,844	of which in selected chromosomes
#  92,067	of which with reference sequence
#  82,838	final bins
# Calculating correction for GC content and mappability
#     Calculating fit for sample 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup (1 of 4) ...
#     Calculating fit for sample 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup (2 of 4) ...
#     Calculating fit for sample 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup (3 of 4) ...
#     Calculating fit for sample 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup (4 of 4) ...
# Done.
# Applying median normalization ...
# Smoothing outliers ...
#   |............................                                          |  41%
#   ordinary text without R code
#
#   |...............................                                       |  44%
# label: dewaving (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
# Loading required package: gtools
# Applying deWaving ...
#   |.................................                                     |  47%
#   ordinary text without R code
#
#   |...................................                                   |  50%
# label: calling (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
# Performing segmentation:
# NA
# NA
# NA
# NA
# EM algorithm started ...
#
# 396456817489634211.8133.5757090258587921404.4447757090291525847404.4698.3
# Calling iteration1:
#
# optim results
# time: 5
# minimum: 166291.159687242
# 4166222.956616616-0.942417202498039-0.4885436389859240.02026510276985380.4216571805574440.7208277112423691.149409018022460.2543228408899220.138007951881070.08745118237233790.1635645834340240.1811099357506910.372359869605834
# 396607117494564211.9133.5757090258587921404.4447757090291525847404.4698.3
# Calling iteration2:
#
# optim results
# time: 3
# minimum: 166233.749610535
# 4166202.654310735-0.913194137208366-0.4826057028706990.02397902869847170.4334344024056070.7409610049725561.165215827578470.3147507272466880.1224182392514990.06348641257488140.1274983422066360.1782651254057860.361680440992586
# 396607117494564211.9133.5757090258587921404.4447757090291525847404.4698.3
# Calling iteration3:
#
# optim results
# time: 3
# minimum: 166215.634232757
# 4166200.008672904-0.892964171417285-0.4778746022997270.02393314174626950.433731119810840.7414682467271421.164157507357930.4088585371335470.1190099435944730.05805270463507570.1086165602002820.1453682675935230.329675162709935
# EM algorithm done ...
#
# Computing posterior probabilities for all segments ...
#
# Total time:0minutes
#
# Adjusting segmented data for cellularity ...
#
# Cellularity sample1: 1
#
# Cellularity sample2: 1
#
# Cellularity sample3: 1
#
# Cellularity sample4: 1
#
# Adjusting normalized data for cellularity ...
#
# Cellularity sample1: 1
#
# Cellularity sample2: 1
#
# Cellularity sample3: 1
#
# Cellularity sample4: 1
#
# 1
# 396855417943527212136.9757090258587921404.4447757090291525847404.4698.3
# 396857218357725212140.1757090258587921404.4447757090291525847404.4698.3
# 396857018357722212140.1757090258587921404.4447757090291525847404.4698.3
# 396859719020447212145.2757090258587921404.4447757090291525847404.4698.3
# 396866119020558212145.2757090258587921404.4447757090291525847404.4698.3
# 396867019020562212145.2757090258587921404.4447757090291525847404.4698.3
# 396867919020566212145.2757090258587921404.4447757090291525847404.4698.3
# 396868819020570212145.2757090258587921404.4447757090291525847404.4698.3
# 396869719020574212145.2757090258587921404.4447757090291525847404.4698.3
# 396870319020577212145.2757090258587921404.4447757090291525847404.4698.3
# 396872419020615212145.2757090258587921404.4447757090291525847404.4698.3
# 396914719020942212145.2757090258587921404.4447757090291525847404.4698.3
# 2
# 396916519766494212150.9757090258587921404.4447757090291525847404.4698.3
# 396916719766497212150.9757090258587921404.4447757090291525847404.4698.3
# 396916519766494212150.9757090258587921404.4447757090291525847404.4698.3
# 396916819849323212151.5757090258587921404.4447757090291525847404.4698.3
# 396916819849323212151.5757090258587921404.4447757090291525847404.4698.3
# 396917719849327212151.5757090258587921404.4447757090291525847404.4698.3
# 396918619849331212151.5757090258587921404.4447757090291525847404.4698.3
# 396919519849335212151.5757090258587921404.4447757090291525847404.4698.3
# 396920419849339212151.5757090258587921404.4447757090291525847404.4698.3
# 396921019849342212151.5757090258587921404.4447757090291525847404.4698.3
# 396923119849380212151.5757090258587921404.4447757090291525847404.4698.3
# 397337021267881212.3162.3757090258587921404.4447757090291525847404.4698.3
# 3
# 397337621764912212.3166.1757090258587921404.4447757090291525847404.4698.3
# 397337821764915212.3166.1757090258587921404.4447757090291525847404.4698.3
# 397337621764912212.3166.1757090258587921404.4447757090291525847404.4698.3
# 397337921847745212.3166.7757090258587921404.4447757090291525847404.4698.3
# 397337421682067212.3165.5757090258587921404.4447757090291525847404.4698.3
# 397338321682071212.3165.5757090258587921404.4447757090291525847404.4698.3
# 397339221682075212.3165.5757090258587921404.4447757090291525847404.4698.3
# 397340121682079212.3165.5757090258587921404.4447757090291525847404.4698.3
# 397341021682083212.3165.5757090258587921404.4447757090291525847404.4698.3
# 397341621682086212.3165.5757090258587921404.4447757090291525847404.4698.3
# 397343721682124212.3165.5757090258587921404.4447757090291525847404.4698.3
# 397337021930601212.3167.4757090258587921404.4447757090291525847404.4698.3
# 4
# 397337622427632212.3171.2757090258587921404.4447757090291525847404.4698.3
# 397337822427635212.3171.2757090258587921404.4447757090291525847404.4698.3
# 397337622427632212.3171.2757090258587921404.4447757090291525847404.4698.3
# 397337922510512212.3171.8757090258587921404.4447757090291525847404.4698.3
# 397337422344834212.3170.5757090258587921404.4447757090291525847404.4698.3
# 397338322344838212.3170.5757090258587921404.4447757090291525847404.4698.3
# 397339222344842212.3170.5757090258587921404.4447757090291525847404.4698.3
# 397340122344846212.3170.5757090258587921404.4447757090291525847404.4698.3
# 397341022344850212.3170.5757090258587921404.4447757090291525847404.4698.3
# 397341622344853212.3170.5757090258587921404.4447757090291525847404.4698.3
# 397343722344891212.3170.5757090258587921404.4447757090291525847404.4698.3
# 397337022593346212.3172.4757090258587921404.4447757090291525847404.4698.3
# FINISHED!
#
# Total time:0minutes
#
#   |.....................................                                 |  53%
#   ordinary text without R code
#
#   |.......................................                               |  56%
# label: freqPlots (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
# Plotting sample 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup (10,991,657 reads) (1 of 4) ...
# Plotting sample 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup (5,984,265 reads) (2 of 4) ...
# Plotting sample 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup (3,006,820 reads) (3 of 4) ...
# Plotting sample 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup (5,509,831 reads) (4 of 4) ...
# Plotting sample 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup (10,991,657 reads) (1 of 4) ...
# Plotting sample 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup (5,984,265 reads) (2 of 4) ...
# Plotting sample 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup (3,006,820 reads) (3 of 4) ...
# Plotting sample 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup (5,509,831 reads) (4 of 4) ...
#   |..........................................                            |  59%
#   ordinary text without R code
#
#   |............................................                          |  62%
# label: calledPlots (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
# Plotting sample 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup (10,991,657 reads) (1 of 1) ...
# Plotting sample 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup (5,984,265 reads) (1 of 1) ...
# Plotting sample 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup (3,006,820 reads) (1 of 1) ...
# Plotting sample 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup (5,509,831 reads) (1 of 1) ...
#   |..............................................                        |  66%
#   ordinary text without R code
#
#   |................................................                      |  69%
# label: segmentsPlots (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
# Plotting sample 5177_20_B16PON_C-050_p6_ACACAGAA_S39_R1_001.markdup (10,991,657 reads) (1 of 1) ...
# Plotting sample 5177_21_B16PON_C-051_p9_ACGCTCGA_S33_R1_001.markdup (5,984,265 reads) (1 of 1) ...
# Plotting sample 5177_22_B16PON_C-052_p6_ACGTATCA_S40_R1_001.markdup (3,006,820 reads) (1 of 1) ...
# Plotting sample 5177_23_B16PON_C-053_p4_AGATCGCA_S41_R1_001.markdup (5,509,831 reads) (1 of 1) ...
#   |..................................................                    |  72%
#   ordinary text without R code
#
#   |....................................................                  |  75%
# label: Stats (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#   |.......................................................               |  78%
#   ordinary text without R code
#
#   |.........................................................             |  81%
# label: cghregions (with options)
# List of 2
#  $ message: logi FALSE
#  $ warning: logi FALSE
#
#   |...........................................................           |  84%
#   ordinary text without R code
#
#   |.............................................................         |  88%
# label: segments (with options)
# List of 2
#  $ warning: logi FALSE
#  $ message: logi FALSE
#
#   |...............................................................       |  91%
#   ordinary text without R code
#
#   |..................................................................    |  94%
# label: TBL (with options)
# List of 2
#  $ warning: logi FALSE
#  $ message: logi FALSE
#
# Loading required package: CGHcall
# Loading required package: DNAcopy
# Loading required package: snowfall
# Loading required package: snow
#
# Attaching package: 'snow'
#
# The following objects are masked from 'package:BiocGenerics':
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, clusterSplit, parApply, parCapply,
#     parLapply, parRapply, parSapply
#
# The following objects are masked from 'package:parallel':
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, clusterSplit, makeCluster, parApply,
#     parCapply, parLapply, parRapply, parSapply, splitIndices,
#     stopCluster
#
#
# Attaching package: 'CGHcall'
#
# The following object is masked from 'package:BiocGenerics':
#
#     normalize
#
# Loading required package: GenomicRanges
# Loading required package: stats4
# Loading required package: S4Vectors
#
# Attaching package: 'S4Vectors'
#
# The following object is masked from 'package:future':
#
#     values
#
# The following object is masked from 'package:base':
#
#     expand.grid
#
# Loading required package: IRanges
#
# Attaching package: 'IRanges'
#
# The following object is masked _by_ '.GlobalEnv':
#
#     shift
#
# Loading required package: GenomeInfoDb
#
# Attaching package: 'GeneBreak'
#
# The following object is masked _by_ '.GlobalEnv':
#
#     sampleNames
#
# The following object is masked from 'package:CGHcall':
#
#     segmentData
#
# The following object is masked from 'package:Biobase':
#
#     sampleNames
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ tibble  3.1.1     ✔ purrr   0.3.4
# ✔ tidyr   1.1.3     ✔ dplyr   1.0.6
# ✔ readr   1.4.0     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::collapse()   masks IRanges::collapse()
# ✖ dplyr::combine()    masks Biobase::combine(), BiocGenerics::combine()
# ✖ dplyr::desc()       masks IRanges::desc()
# ✖ tidyr::expand()     masks S4Vectors::expand()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::first()      masks S4Vectors::first()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ ggplot2::Position() masks BiocGenerics::Position(), base::Position()
# ✖ purrr::reduce()     masks GenomicRanges::reduce(), IRanges::reduce()
# ✖ dplyr::rename()     masks S4Vectors::rename()
# ✖ dplyr::select()     masks MASS::select()
# ✖ dplyr::slice()      masks IRanges::slice()
#   |....................................................................  |  97%
#   ordinary text without R code
#
#   |......................................................................| 100%
# label: unnamed-chunk-2
#
# output file: QDNASeq_hg38_oldOrganoids_30kb.knit.md
#
# /home/l.gonzalez/anaconda3/bin/pandoc +RTS -K512m -RTS QDNASeq_hg38_oldOrganoids_30kb.knit.md --to html4 --from markdown+autolink_bare_uris+tex_math_single_backslash --output QDNASeq_hg38_oldOrganoids_30kb.html --lua-filter /DATA/home/l.gonzalez/R/x86_64-pc-linux-gnu-library/3.6/rmarkdown/rmarkdown/lua/pagebreak.lua --lua-filter /DATA/home/l.gonzalez/R/x86_64-pc-linux-gnu-library/3.6/rmarkdown/rmarkdown/lua/latex-div.lua --self-contained --variable bs3=TRUE --standalone --section-divs --template /DATA/home/l.gonzalez/R/x86_64-pc-linux-gnu-library/3.6/rmarkdown/rmd/h/default.html --no-highlight --variable highlightjs=1 --variable theme=bootstrap --include-in-header /tmp/RtmppSwiEK/rmarkdown-str22b0f3711cd91.html --mathjax --variable 'mathjax-url:https://mathjax.rstudio.com/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML'
# Output created: QDNASeq_hg38_oldOrganoids_30kb.html
# There were 50 or more warnings (use warnings() to see the first 50)
# >
# >

# %%
#! selectR-config --select 3.6
#! selectR-config --select 4.0
# Out:
# [1] TRUE

# %%
#!R
#!/opt/R/4.0.4/bin/Rscript
# Out:
# R version 3.6.3 (2020-02-29) -- "Holding the Windsock"
# Copyright (C) 2020 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu (64-bit)
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
#   Natural language support but running in an English locale
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# >

# %%
#!ls /usr/local/bin/
# Out:
# alignmentSieve		  google-oauthlib-tool	    pyrsa-keygen
# bamCompare		  import_pb_to_tensorboard  pyrsa-priv2pub
# bamCoverage		  markdown_py		    pyrsa-sign
# bamPEFragmentSize	  multiBamSummary	    pyrsa-verify
# bigwigCompare		  multiBigwigSummary	    saved_model_cli
# computeGCBias		  pbr			    sphinx-apidoc
# computeMatrix		  plotCorrelation	    sphinx-autogen
# computeMatrixOperations   plotCoverage		    sphinx-build
# correctGCBias		  plotEnrichment	    sphinx-quickstart
# deeptools		  plotFingerprint	    tensorboard
# estimateReadFiltering	  plotHeatmap		    tflite_convert
# estimateScaleFactor	  plotPCA		    tf_upgrade_v2
# estimator_ckpt_converter  plotProfile		    toco
# f2py			  pybabel		    toco_from_protos
# f2py3			  pyrsa-decrypt		    tqdm
# f2py3.8			  pyrsa-encrypt		    wheel

# %%
# !multiqc /DATA/share/pipelines/lgleon/test/testCode_steps_Nousefuldata/testdata/fastq/
# Out:
# [WARNING]         multiqc : MultiQC Version v1.11 now available!
# [INFO   ]         multiqc : This is MultiQC v1.10.1
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching   : /DATA/share/pipelines/lgleon/test/testCode_steps_Nousefuldata/testdata/fastq
# Searching   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 20/20  20
# [WARNING]         multiqc : No analysis results found. Cleaning up..
# [INFO   ]         multiqc : MultiQC complete

# %%
# !cutapt
# Out:
# /bin/bash: cutapt: command not found

# %%
# !conda activate base
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
